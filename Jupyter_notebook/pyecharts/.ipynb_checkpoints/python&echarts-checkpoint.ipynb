# %%
import pymysql
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pyecharts import Bar

# %%
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

# %%
import os
print(os.getcwd())
# Out:
# E:\cmder\myfiles\PythonAnalysis\Jupyter_notebook\pyecharts

# %%
title = 'bar chart'
index = pd.date_range('2018/1/1', periods=10, freq='M')
df1 = pd.DataFrame(np.random.randn(10), index=index)
df2 = pd.DataFrame(np.random.randn(10), index=index)

dtvalue1 = [i[0] for i in df1.values]
dtvalue2 = [i[0] for i in df2.values]
_index = [i for i in df1.index.format()]

bar = Bar(title, 'Profit and loss situation')
bar.add('profit', _index, dtvalue1)
bar.add('loss', _index, dtvalue2)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="d1eac0ce659346e281b3bb849ed70fe4" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_d1eac0ce659346e281b3bb849ed70fe4 = echarts.init(document.getElementById('d1eac0ce659346e281b3bb849ed70fe4'), 'light', {renderer: 'canvas'});
#
# var option_d1eac0ce659346e281b3bb849ed70fe4 = {
#     "title": [
#         {
#             "text": "bar chart",
#             "subtext": "Profit and loss situation",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 6851450,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "profit",
#             "data": [
#                 0.6983692862650684,
#                 0.16094995281140032,
#                 1.0432946951486475,
#                 1.5725899666568492,
#                 -0.015692254336532797,
#                 -0.19370712018833727,
#                 0.5576933016971306,
#                 0.34493179307415456,
#                 -0.7240359130632388,
#                 0.10942531165033
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 6851450
#         },
#         {
#             "type": "bar",
#             "name": "loss",
#             "data": [
#                 0.2894321197019867,
#                 0.054376452600008895,
#                 -0.8569356555007429,
#                 1.2734010692177855,
#                 0.08443246352845725,
#                 -0.8903623416954324,
#                 -0.7359613189307656,
#                 -1.1078515642069071,
#                 1.9375765638129734,
#                 -0.7809745079872927
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 6851450
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "profit",
#                 "loss"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "2018-01-31",
#                 "2018-02-28",
#                 "2018-03-31",
#                 "2018-04-30",
#                 "2018-05-31",
#                 "2018-06-30",
#                 "2018-07-31",
#                 "2018-08-31",
#                 "2018-09-30",
#                 "2018-10-31"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_d1eac0ce659346e281b3bb849ed70fe4.setOption(option_d1eac0ce659346e281b3bb849ed70fe4);
#
#     });
# </script>

# %%
print(os.chdir(r'd:\工具\test'), os.listdir(), sep='\n')
# Out:
# None
# ['debug.log', 'demo.twb', 'demo.twb 个文件', 'personal', 'sales.pickle', 'sql汇总.txt', '会员购进明细', '佛山门特', '原始数据', '发至采购的数据', '客流客单对比', '明细.xlsx', '明细分列.xlsx', '月返利数据统计', '每日数据统计', '运营管理部数据', '销售明细.accdb', '销售明细2017.xlsx', '销售明细2018-1.xlsx', '销售明细2018.xlsx']

# %%
df = pd.read_pickle('./sales.pickle')

# %%
print(df.head(), df.describe())
# Out:
#      年份  月份                销售时间                   小票号     商品代码           商品名称  \
# 0  2017   1 2017-01-01 08:24:51  16009001005170000001  1324700  贝伐珠单抗注射液(安维汀)
# 1  2017   1 2017-01-01 08:33:25  16009101001170000001  2826800          人血白蛋白
# 2  2017   1 2017-01-01 08:34:36  16009101001170000002  2826800          人血白蛋白
# 3  2017   1 2017-01-01 08:35:27  16009101001170000003  8724900     一次性使用婴儿护脐包
# 4  2017   1 2017-01-01 08:36:20  16009101001170000004  2826800          人血白蛋白
#
#               规格   数量   门店名称                                      生产厂家 定价客户  \
# 0  100mg(4ml)*1瓶  5.0  湛江大药房  Roche Diagnostics GmbH(原:Genentech Inc.)  NaN
# 1    20%10g/50ml  1.0  佛一大药房                美国Grifols Biologicals Inc.  NaN
# 2    20%10g/50ml  2.0  佛一大药房                美国Grifols Biologicals Inc.  NaN
# 3   A型(7cm*42cm)  1.0  佛一大药房                              广州健朗医用科技有限公司  NaN
# 4    20%10g/50ml  2.0  佛一大药房                美国Grifols Biologicals Inc.  NaN
#
#      含税单价    折让后金额  批次含税进价     毛利率  补差  补差合计   合计毛利额     实际毛利率
# 0  5298.0  26490.0  4745.0  0.1044 NaN   NaN  2765.0  0.104379
# 1   430.0    430.0   360.0  0.1628 NaN   NaN    70.0  0.162791
# 2   430.0    860.0   360.0  0.1628 NaN   NaN   140.0  0.162791
# 3    33.0     33.0    22.8  0.3091 NaN   NaN    10.2  0.309091
# 4   430.0    860.0   360.0  0.1628 NaN   NaN   140.0  0.162791                    年份            月份           小票号            数量          含税单价  \
# count  1.632701e+06  1.632701e+06  1.632701e+06  1.632701e+06  1.632701e+06
# mean   2.017732e+03  6.303447e+00  1.597657e+19  3.294218e+00  3.574266e+02
# std    4.427270e-01  3.069047e+00  3.981150e+17  1.776705e+01  1.669986e+03
# min    2.017000e+03  1.000000e+00  1.110900e+19 -1.000000e+03  0.000000e+00
# 25%    2.017000e+03  4.000000e+00  1.600910e+19  1.000000e+00  3.000000e+01
# 50%    2.018000e+03  6.000000e+00  1.600911e+19  1.000000e+00  6.200000e+01
# 75%    2.018000e+03  9.000000e+00  1.600911e+19  2.000000e+00  1.980000e+02
# max    2.018000e+03  1.200000e+01  1.600940e+19  6.000000e+03  5.900000e+04
#
#               折让后金额        批次含税进价           毛利率            补差          补差合计  \
# count  1.632700e+06  1.632701e+06  1.632701e+06  20628.000000  20628.000000
# mean   6.308400e+02  3.229972e+02 -7.302882e-01    574.688120    997.705082
# std    2.256528e+03  1.623743e+03  6.846060e+02   1851.850254   2291.046183
# min   -5.350000e+04  0.000000e+00 -5.050490e+05     -0.010000 -33477.880000
# 25%    3.980000e+01  2.236000e+01  1.373000e-01     75.750000     75.750000
# 50%    1.140000e+02  4.876000e+01  1.894000e-01    201.000000    209.380000
# 75%    4.050000e+02  1.546600e+02  2.464000e-01    214.470000   1072.350000
# max    1.110000e+05  5.651788e+04  1.000000e+00  35218.880000  35218.880000
#
#               合计毛利额         实际毛利率
# count  1.632694e+06  1.632698e+06
# mean   7.531527e+01 -7.098781e-01
# std    1.963128e+02  6.709498e+02
# min   -1.512335e+04 -4.949740e+05
# 25%    7.080000e+00  1.375000e-01
# 50%    2.094000e+01  1.897959e-01
# 75%    7.000000e+01  2.464286e-01
# max    1.211600e+04  1.000000e+00
