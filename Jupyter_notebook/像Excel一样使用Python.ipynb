# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({'id':[1001,1002,1003,1004,1005,1006],
                  'date':pd.date_range('20130102',periods=6),
                  'city':['Beijing','SH',' guangzhou ',
                          'Shenzhen','shanghai','BEIJING '],
                  'age':[23,44,54,32,34,32],
                  'category':['100-A','100-B','120-A','110-C','210-A','130-F'],
                  'price':[1200,np.nan,2133,5433,np.nan,4432]},
                 columns=['id','date','city','category','age','price'])

# %%
df
# Out:
#      id       date         city category  age   price
# 0  1001 2013-01-02      Beijing    100-A   23  1200.0
# 1  1002 2013-01-03           SH    100-B   44     NaN
# 2  1003 2013-01-04   guangzhou     120-A   54  2133.0
# 3  1004 2013-01-05     Shenzhen    110-C   32  5433.0
# 4  1005 2013-01-06     shanghai    210-A   34     NaN
# 5  1006 2013-01-07     BEIJING     130-F   32  4432.0

# %%
df.shape
# Out:
# (6, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
# id          6 non-null int64
# date        6 non-null datetime64[ns]
# city        6 non-null object
# category    6 non-null object
# age         6 non-null int64
# price       4 non-null float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(2)
# memory usage: 368.0+ bytes

# %%
df.dtypes
# Out:
# id                   int64
# date        datetime64[ns]
# city                object
# category            object
# age                  int64
# price              float64
# dtype: object

# %%
df['city'].dtype
# Out:
# dtype('O')

# %%
df.isnull()
# Out:
#       id   date   city  category    age  price
# 0  False  False  False     False  False  False
# 1  False  False  False     False  False   True
# 2  False  False  False     False  False  False
# 3  False  False  False     False  False  False
# 4  False  False  False     False  False   True
# 5  False  False  False     False  False  False

# %%
df['price'].isnull()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# 5    False
# Name: price, dtype: bool

# %%
df[['price','city']].isnull()
# Out:
#    price   city
# 0  False  False
# 1   True  False
# 2  False  False
# 3  False  False
# 4   True  False
# 5  False  False

# %%
df['price'].unique()
# Out:
# array([1200.,   nan, 2133., 5433., 4432.])

# %%
df['age'].unique()
# Out:
# array([23, 44, 54, 32, 34], dtype=int64)

# %%
df.head()
# Out:
#      id       date         city category  age   price
# 0  1001 2013-01-02      Beijing    100-A   23  1200.0
# 1  1002 2013-01-03           SH    100-B   44     NaN
# 2  1003 2013-01-04   guangzhou     120-A   54  2133.0
# 3  1004 2013-01-05     Shenzhen    110-C   32  5433.0
# 4  1005 2013-01-06     shanghai    210-A   34     NaN

# %%
df.tail()
# Out:
#      id       date         city category  age   price
# 1  1002 2013-01-03           SH    100-B   44     NaN
# 2  1003 2013-01-04   guangzhou     120-A   54  2133.0
# 3  1004 2013-01-05     Shenzhen    110-C   32  5433.0
# 4  1005 2013-01-06     shanghai    210-A   34     NaN
# 5  1006 2013-01-07     BEIJING     130-F   32  4432.0

# %%
df.columns
# Out:
# Index(['id', 'date', 'city', 'category', 'age', 'price'], dtype='object')

# %% [markdown]
# **返回一个删除了包含na值的记录的新表**

# %%
df.dropna(how='any')
# Out:
#      id       date         city category  age   price
# 0  1001 2013-01-02      Beijing    100-A   23  1200.0
# 2  1003 2013-01-04   guangzhou     120-A   54  2133.0
# 3  1004 2013-01-05     Shenzhen    110-C   32  5433.0
# 5  1006 2013-01-07     BEIJING     130-F   32  4432.0

# %%
df.fillna(value=0)
# Out:
#      id       date         city category  age   price
# 0  1001 2013-01-02      Beijing    100-A   23  1200.0
# 1  1002 2013-01-03           SH    100-B   44     0.0
# 2  1003 2013-01-04   guangzhou     120-A   54  2133.0
# 3  1004 2013-01-05     Shenzhen    110-C   32  5433.0
# 4  1005 2013-01-06     shanghai    210-A   34     0.0
# 5  1006 2013-01-07     BEIJING     130-F   32  4432.0

# %%
df['price'] = df['price'].fillna(df['price'].mean())

# %%
df['city']
# Out:
# 0        Beijing
# 1             SH
# 2     guangzhou
# 3       Shenzhen
# 4       shanghai
# 5       BEIJING
# Name: city, dtype: object

# %%
len(df.iloc[2,2])
# Out:
# 11

# %%
df['city'] = df['city'].map(str.strip)

# %%
len(df.iloc[2,2])
# Out:
# 9

# %%
df['city'] = df['city'].str.lower()

# %%
df
# Out:
#      id       date       city category  age   price
# 0  1001 2013-01-02    beijing    100-A   23  1200.0
# 1  1002 2013-01-03         sh    100-B   44  3299.5
# 2  1003 2013-01-04  guangzhou    120-A   54  2133.0
# 3  1004 2013-01-05   shenzhen    110-C   32  5433.0
# 4  1005 2013-01-06   shanghai    210-A   34  3299.5
# 5  1006 2013-01-07    beijing    130-F   32  4432.0

# %%
df['price'].dtype
# Out:
# dtype('float64')

# %%
df['price'].astype('int')
# Out:
# 0    1200
# 1    3299
# 2    2133
# 3    5433
# 4    3299
# 5    4432
# Name: price, dtype: int32

# %%
df= df.rename(columns={'category':'category-size'})

# %%
df
# Out:
#      id       date       city category-size  age   price
# 0  1001 2013-01-02    beijing         100-A   23  1200.0
# 1  1002 2013-01-03         sh         100-B   44  3299.5
# 2  1003 2013-01-04  guangzhou         120-A   54  2133.0
# 3  1004 2013-01-05   shenzhen         110-C   32  5433.0
# 4  1005 2013-01-06   shanghai         210-A   34  3299.5
# 5  1006 2013-01-07    beijing         130-F   32  4432.0

# %%
df['city'].drop_duplicates()
# Out:
# 0      beijing
# 1           sh
# 2    guangzhou
# 3     shenzhen
# 4     shanghai
# Name: city, dtype: object

# %%
df['city'].drop_duplicates(keep='last')
# Out:
# 1           sh
# 2    guangzhou
# 3     shenzhen
# 4     shanghai
# 5      beijing
# Name: city, dtype: object

# %%
df['city']= df['city'].replace('sh','shanghai')

# %%
df
# Out:
#      id       date       city category-size  age   price
# 0  1001 2013-01-02    beijing         100-A   23  1200.0
# 1  1002 2013-01-03   shanghai         100-B   44  3299.5
# 2  1003 2013-01-04  guangzhou         120-A   54  2133.0
# 3  1004 2013-01-05   shenzhen         110-C   32  5433.0
# 4  1005 2013-01-06   shanghai         210-A   34  3299.5
# 5  1006 2013-01-07    beijing         130-F   32  4432.0

# %%
df1=pd.DataFrame({'id':[1001,1002,1003,1004,1005,1006,1007,1008],
                 'gender':['male','female','male','female','male',
                          'female','female','male'],
                 'pay':['y','n','y','n','y','y','n','n'],
                 'm-point':[10,11,11,123,42,213,23,43]})

# %%
df1
# Out:
#    gender    id  m-point pay
# 0    male  1001       10   y
# 1  female  1002       11   n
# 2    male  1003       11   y
# 3  female  1004      123   n
# 4    male  1005       42   y
# 5  female  1006      213   y
# 6  female  1007       23   n
# 7    male  1008       43   n

# %%
df_inner=pd.merge(df,df1,how='inner')

# %%
df_inner
# Out:
#      id       date       city category-size  age   price  gender  m-point pay
# 0  1001 2013-01-02    beijing         100-A   23  1200.0    male       10   y
# 1  1002 2013-01-03   shanghai         100-B   44  3299.5  female       11   n
# 2  1003 2013-01-04  guangzhou         120-A   54  2133.0    male       11   y
# 3  1004 2013-01-05   shenzhen         110-C   32  5433.0  female      123   n
# 4  1005 2013-01-06   shanghai         210-A   34  3299.5    male       42   y
# 5  1006 2013-01-07    beijing         130-F   32  4432.0  female      213   y

# %%
df_left=pd.merge(df,df1,how='left')

# %%
df_left
# Out:
#      id       date       city category-size  age   price  gender  m-point pay
# 0  1001 2013-01-02    beijing         100-A   23  1200.0    male       10   y
# 1  1002 2013-01-03   shanghai         100-B   44  3299.5  female       11   n
# 2  1003 2013-01-04  guangzhou         120-A   54  2133.0    male       11   y
# 3  1004 2013-01-05   shenzhen         110-C   32  5433.0  female      123   n
# 4  1005 2013-01-06   shanghai         210-A   34  3299.5    male       42   y
# 5  1006 2013-01-07    beijing         130-F   32  4432.0  female      213   y

# %%
df_right=pd.merge(df,df1,how='right')

# %%
df_right
# Out:
#      id       date       city category-size   age   price  gender  m-point pay
# 0  1001 2013-01-02    beijing         100-A  23.0  1200.0    male       10   y
# 1  1002 2013-01-03   shanghai         100-B  44.0  3299.5  female       11   n
# 2  1003 2013-01-04  guangzhou         120-A  54.0  2133.0    male       11   y
# 3  1004 2013-01-05   shenzhen         110-C  32.0  5433.0  female      123   n
# 4  1005 2013-01-06   shanghai         210-A  34.0  3299.5    male       42   y
# 5  1006 2013-01-07    beijing         130-F  32.0  4432.0  female      213   y
# 6  1007        NaT        NaN           NaN   NaN     NaN  female       23   n
# 7  1008        NaT        NaN           NaN   NaN     NaN    male       43   n

# %%
df_outer=pd.merge(df,df1,how='outer')

# %%
df_outer
# Out:
#      id       date       city category-size   age   price  gender  m-point pay
# 0  1001 2013-01-02    beijing         100-A  23.0  1200.0    male       10   y
# 1  1002 2013-01-03   shanghai         100-B  44.0  3299.5  female       11   n
# 2  1003 2013-01-04  guangzhou         120-A  54.0  2133.0    male       11   y
# 3  1004 2013-01-05   shenzhen         110-C  32.0  5433.0  female      123   n
# 4  1005 2013-01-06   shanghai         210-A  34.0  3299.5    male       42   y
# 5  1006 2013-01-07    beijing         130-F  32.0  4432.0  female      213   y
# 6  1007        NaT        NaN           NaN   NaN     NaN  female       23   n
# 7  1008        NaT        NaN           NaN   NaN     NaN    male       43   n

# %%
df_inner = df_inner.set_index('id')

# %%
df_inner.sort_values(by='age')
# Out:
#            date       city category-size  age   price  gender  m-point pay
# id
# 1001 2013-01-02    beijing         100-A   23  1200.0    male       10   y
# 1004 2013-01-05   shenzhen         110-C   32  5433.0  female      123   n
# 1006 2013-01-07    beijing         130-F   32  4432.0  female      213   y
# 1005 2013-01-06   shanghai         210-A   34  3299.5    male       42   y
# 1002 2013-01-03   shanghai         100-B   44  3299.5  female       11   n
# 1003 2013-01-04  guangzhou         120-A   54  2133.0    male       11   y

# %%
df_inner.sort_values(by=['age','price'])
# Out:
#            date       city category-size  age   price  gender  m-point pay
# id
# 1001 2013-01-02    beijing         100-A   23  1200.0    male       10   y
# 1006 2013-01-07    beijing         130-F   32  4432.0  female      213   y
# 1004 2013-01-05   shenzhen         110-C   32  5433.0  female      123   n
# 1005 2013-01-06   shanghai         210-A   34  3299.5    male       42   y
# 1002 2013-01-03   shanghai         100-B   44  3299.5  female       11   n
# 1003 2013-01-04  guangzhou         120-A   54  2133.0    male       11   y

# %%
df_inner.sort_index()
# Out:
#            date       city category-size  age   price  gender  m-point pay
# id
# 1001 2013-01-02    beijing         100-A   23  1200.0    male       10   y
# 1002 2013-01-03   shanghai         100-B   44  3299.5  female       11   n
# 1003 2013-01-04  guangzhou         120-A   54  2133.0    male       11   y
# 1004 2013-01-05   shenzhen         110-C   32  5433.0  female      123   n
# 1005 2013-01-06   shanghai         210-A   34  3299.5    male       42   y
# 1006 2013-01-07    beijing         130-F   32  4432.0  female      213   y

# %%
df_inner['group']=np.where(df_inner['price']>3000,'high','low')

# %%
df_inner
# Out:
#            date       city category-size  age   price  gender  m-point pay  \
# id
# 1001 2013-01-02    beijing         100-A   23  1200.0    male       10   y
# 1002 2013-01-03   shanghai         100-B   44  3299.5  female       11   n
# 1003 2013-01-04  guangzhou         120-A   54  2133.0    male       11   y
# 1004 2013-01-05   shenzhen         110-C   32  5433.0  female      123   n
# 1005 2013-01-06   shanghai         210-A   34  3299.5    male       42   y
# 1006 2013-01-07    beijing         130-F   32  4432.0  female      213   y
#
#      group
# id
# 1001   low
# 1002  high
# 1003   low
# 1004  high
# 1005  high
# 1006  high

# %%
df_inner.loc[((df_inner['city']=='beijing')&(df_inner['price']>=3000),'sign')]=1

# %%
df_inner
# Out:
#            date       city category-size  age   price  gender  m-point pay  \
# id
# 1001 2013-01-02    beijing         100-A   23  1200.0    male       10   y
# 1002 2013-01-03   shanghai         100-B   44  3299.5  female       11   n
# 1003 2013-01-04  guangzhou         120-A   54  2133.0    male       11   y
# 1004 2013-01-05   shenzhen         110-C   32  5433.0  female      123   n
# 1005 2013-01-06   shanghai         210-A   34  3299.5    male       42   y
# 1006 2013-01-07    beijing         130-F   32  4432.0  female      213   y
#
#      group  sign
# id
# 1001   low   NaN
# 1002  high   NaN
# 1003   low   NaN
# 1004  high   NaN
# 1005  high   NaN
# 1006  high   1.0

# %%
split = pd.DataFrame((x.split('-') for x in df_inner['category-size']), 
             index=df_inner.index, columns=['category','size'])

# %%
split
# Out:
#      category size
# id
# 1001      100    A
# 1002      100    B
# 1003      120    A
# 1004      110    C
# 1005      210    A
# 1006      130    F

# %%
df_inner=pd.merge(df_inner, split, right_index=True, left_index=True)

# %%
df_inner
# Out:
#            date       city category-size  age   price  gender  m-point pay  \
# id
# 1001 2013-01-02    beijing         100-A   23  1200.0    male       10   y
# 1002 2013-01-03   shanghai         100-B   44  3299.5  female       11   n
# 1003 2013-01-04  guangzhou         120-A   54  2133.0    male       11   y
# 1004 2013-01-05   shenzhen         110-C   32  5433.0  female      123   n
# 1005 2013-01-06   shanghai         210-A   34  3299.5    male       42   y
# 1006 2013-01-07    beijing         130-F   32  4432.0  female      213   y
#
#      group  sign category size
# id
# 1001   low   NaN      100    A
# 1002  high   NaN      100    B
# 1003   low   NaN      120    A
# 1004  high   NaN      110    C
# 1005  high   NaN      210    A
# 1006  high   1.0      130    F

# %%
df_inner=pd.merge(df_inner, split)

# %%
df_inner
# Out:
#         date       city category-size  age   price  gender  m-point pay group  \
# 0 2013-01-02    beijing         100-A   23  1200.0    male       10   y   low
# 1 2013-01-03   shanghai         100-B   44  3299.5  female       11   n  high
# 2 2013-01-04  guangzhou         120-A   54  2133.0    male       11   y   low
# 3 2013-01-05   shenzhen         110-C   32  5433.0  female      123   n  high
# 4 2013-01-06   shanghai         210-A   34  3299.5    male       42   y  high
# 5 2013-01-07    beijing         130-F   32  4432.0  female      213   y  high
#
#    sign category size
# 0   NaN      100    A
# 1   NaN      100    B
# 2   NaN      120    A
# 3   NaN      110    C
# 4   NaN      210    A
# 5   1.0      130    F

# %%
df_inner.loc[3]
# Out:
# date             2013-01-05 00:00:00
# city                        shenzhen
# category-size                  110-C
# age                               32
# price                           5433
# gender                        female
# m-point                          123
# pay                                n
# group                           high
# sign                             NaN
# category                         110
# size                               C
# Name: 3, dtype: object

# %%
df_inner.loc[3:5]
# Out:
#         date      city category-size  age   price  gender  m-point pay group  \
# 3 2013-01-05  shenzhen         110-C   32  5433.0  female      123   n  high
# 4 2013-01-06  shanghai         210-A   34  3299.5    male       42   y  high
# 5 2013-01-07   beijing         130-F   32  4432.0  female      213   y  high
#
#    sign category size
# 3   NaN      110    C
# 4   NaN      210    A
# 5   1.0      130    F

# %%
df_inner.reset_index()
# Out:
#    index       date       city category-size  age   price  gender  m-point  \
# 0      0 2013-01-02    beijing         100-A   23  1200.0    male       10
# 1      1 2013-01-03   shanghai         100-B   44  3299.5  female       11
# 2      2 2013-01-04  guangzhou         120-A   54  2133.0    male       11
# 3      3 2013-01-05   shenzhen         110-C   32  5433.0  female      123
# 4      4 2013-01-06   shanghai         210-A   34  3299.5    male       42
# 5      5 2013-01-07    beijing         130-F   32  4432.0  female      213
#
#   pay group  sign category size
# 0   y   low   NaN      100    A
# 1   n  high   NaN      100    B
# 2   y   low   NaN      120    A
# 3   n  high   NaN      110    C
# 4   y  high   NaN      210    A
# 5   y  high   1.0      130    F

# %%
df_inner = df_inner.set_index('date')

# %%
df_inner
# Out:
#                  city category-size  age   price  gender  m-point pay group  \
# date
# 2013-01-02    beijing         100-A   23  1200.0    male       10   y   low
# 2013-01-03   shanghai         100-B   44  3299.5  female       11   n  high
# 2013-01-04  guangzhou         120-A   54  2133.0    male       11   y   low
# 2013-01-05   shenzhen         110-C   32  5433.0  female      123   n  high
# 2013-01-06   shanghai         210-A   34  3299.5    male       42   y  high
# 2013-01-07    beijing         130-F   32  4432.0  female      213   y  high
#
#             sign category size
# date
# 2013-01-02   NaN      100    A
# 2013-01-03   NaN      100    B
# 2013-01-04   NaN      120    A
# 2013-01-05   NaN      110    C
# 2013-01-06   NaN      210    A
# 2013-01-07   1.0      130    F

# %%
df_inner.loc[:'2013-01-04']
# Out:
#                  city category-size  age   price  gender  m-point pay group  \
# date
# 2013-01-02    beijing         100-A   23  1200.0    male       10   y   low
# 2013-01-03   shanghai         100-B   44  3299.5  female       11   n  high
# 2013-01-04  guangzhou         120-A   54  2133.0    male       11   y   low
#
#             sign category size
# date
# 2013-01-02   NaN      100    A
# 2013-01-03   NaN      100    B
# 2013-01-04   NaN      120    A

# %%
df_inner.loc['2013-01-05']
# Out:
# city             shenzhen
# category-size       110-C
# age                    32
# price                5433
# gender             female
# m-point               123
# pay                     n
# group                high
# sign                  NaN
# category              110
# size                    C
# Name: 2013-01-05 00:00:00, dtype: object

# %%
df_inner.columns
# Out:
# Index(['city', 'category-size', 'age', 'price', 'gender', 'm-point', 'pay',
#        'group', 'sign', 'category', 'size'],
#       dtype='object')

# %%
df_inner['city']
# Out:
# date
# 2013-01-02      beijing
# 2013-01-03     shanghai
# 2013-01-04    guangzhou
# 2013-01-05     shenzhen
# 2013-01-06     shanghai
# 2013-01-07      beijing
# Name: city, dtype: object

# %%
df_inner.iloc[:2,:2]
# Out:
#                 city category-size
# date
# 2013-01-02   beijing         100-A
# 2013-01-03  shanghai         100-B

# %%
df_inner.iloc[[0,2,5],:2]
# Out:
#                  city category-size
# date
# 2013-01-02    beijing         100-A
# 2013-01-04  guangzhou         120-A
# 2013-01-07    beijing         130-F

# %%
df_inner.iloc[[0,2,5],:2]
# Out:
#                  city category-size
# date
# 2013-01-02    beijing         100-A
# 2013-01-04  guangzhou         120-A
# 2013-01-07    beijing         130-F

# %%
df_inner['city'].isin(['beijing'])
# Out:
# date
# 2013-01-02     True
# 2013-01-03    False
# 2013-01-04    False
# 2013-01-05    False
# 2013-01-06    False
# 2013-01-07     True
# Name: city, dtype: bool

# %%
a = df_inner['city'].isin(['beijing','shanghai'])

# %%
df_inner.loc[a]
# Out:
#                 city category-size  age   price  gender  m-point pay group  \
# date
# 2013-01-02   beijing         100-A   23  1200.0    male       10   y   low
# 2013-01-03  shanghai         100-B   44  3299.5  female       11   n  high
# 2013-01-06  shanghai         210-A   34  3299.5    male       42   y  high
# 2013-01-07   beijing         130-F   32  4432.0  female      213   y  high
#
#             sign category size
# date
# 2013-01-02   NaN      100    A
# 2013-01-03   NaN      100    B
# 2013-01-06   NaN      210    A
# 2013-01-07   1.0      130    F

# %%
category=df_inner['category-size']

# %%
pd.DataFrame(category.str[:3])
# Out:
#            category-size
# date
# 2013-01-02           100
# 2013-01-03           100
# 2013-01-04           120
# 2013-01-05           110
# 2013-01-06           210
# 2013-01-07           130

# %%
a = (df_inner['city']=='beijing') & (df_inner['age'] > 25)

# %%
a
# Out:
# date
# 2013-01-02    False
# 2013-01-03    False
# 2013-01-04    False
# 2013-01-05    False
# 2013-01-06    False
# 2013-01-07     True
# dtype: bool

# %%
df_inner[a]
# Out:
#                city category-size  age   price  gender  m-point pay group  \
# date
# 2013-01-07  beijing         130-F   32  4432.0  female      213   y  high
#
#             sign category size
# date
# 2013-01-07   1.0      130    F

# %%
b = (df_inner['city']=='beijing') | (df_inner['age'] > 25)

# %%
c = ['city','age','category-size','gender','price']

# %%
df_inner.loc[b,c]
# Out:
#                  city  age category-size  gender   price
# date
# 2013-01-02    beijing   23         100-A    male  1200.0
# 2013-01-03   shanghai   44         100-B  female  3299.5
# 2013-01-04  guangzhou   54         120-A    male  2133.0
# 2013-01-05   shenzhen   32         110-C  female  5433.0
# 2013-01-06   shanghai   34         210-A    male  3299.5
# 2013-01-07    beijing   32         130-F  female  4432.0

# %%
e = df_inner[b].sort_values(['age'])

# %%
e.index
# Out:
# DatetimeIndex(['2013-01-02', '2013-01-05', '2013-01-07', '2013-01-06',
#                '2013-01-03', '2013-01-04'],
#               dtype='datetime64[ns]', name='date', freq=None)

# %%
e.columns
# Out:
# Index(['city', 'category-size', 'age', 'price', 'gender', 'm-point', 'pay',
#        'group', 'sign', 'category', 'size'],
#       dtype='object')

# %%
e.iloc[1]
# Out:
# city             shenzhen
# category-size       110-C
# age                    32
# price                5433
# gender             female
# m-point               123
# pay                     n
# group                high
# sign                  NaN
# category              110
# size                    C
# Name: 2013-01-05 00:00:00, dtype: object

# %%
f = df_inner.query('city==["beijing","shanghai"]')

# %%
f.price.sum()
# Out:
# 12231.0

# %%
df_inner.groupby('city').count()
# Out:
#            category-size  age  price  gender  m-point  pay  group  sign  \
# city
# beijing                2    2      2       2        2    2      2     1
# guangzhou              1    1      1       1        1    1      1     0
# shanghai               2    2      2       2        2    2      2     0
# shenzhen               1    1      1       1        1    1      1     0
#
#            category  size
# city
# beijing           2     2
# guangzhou         1     1
# shanghai          2     2
# shenzhen          1     1

# %%
df_inner.groupby('city')['price'].count()
# Out:
# city
# beijing      2
# guangzhou    1
# shanghai     2
# shenzhen     1
# Name: price, dtype: int64

# %%
df_inner.groupby(['city','size'])['price'].count()
# Out:
# city       size
# beijing    A       1
#            F       1
# guangzhou  A       1
# shanghai   A       1
#            B       1
# shenzhen   C       1
# Name: price, dtype: int64

# %%
type(df_inner.groupby(['city','size']))
# Out:
# pandas.core.groupby.DataFrameGroupBy

# %%
df_inner.groupby(['city','size']).price.count()
# Out:
# city       size
# beijing    A       1
#            F       1
# guangzhou  A       1
# shanghai   A       1
#            B       1
# shenzhen   C       1
# Name: price, dtype: int64

# %%
df_inner.groupby(['city','size'])['price'].agg([len,np.sum,np.mean])
# Out:
#                 len     sum    mean
# city      size
# beijing   A     1.0  1200.0  1200.0
#           F     1.0  4432.0  4432.0
# guangzhou A     1.0  2133.0  2133.0
# shanghai  A     1.0  3299.5  3299.5
#           B     1.0  3299.5  3299.5
# shenzhen  C     1.0  5433.0  5433.0

# %%
df_inner
# Out:
#                  city category-size  age   price  gender  m-point pay group  \
# date
# 2013-01-02    beijing         100-A   23  1200.0    male       10   y   low
# 2013-01-03   shanghai         100-B   44  3299.5  female       11   n  high
# 2013-01-04  guangzhou         120-A   54  2133.0    male       11   y   low
# 2013-01-05   shenzhen         110-C   32  5433.0  female      123   n  high
# 2013-01-06   shanghai         210-A   34  3299.5    male       42   y  high
# 2013-01-07    beijing         130-F   32  4432.0  female      213   y  high
#
#             sign category size
# date
# 2013-01-02   NaN      100    A
# 2013-01-03   NaN      100    B
# 2013-01-04   NaN      120    A
# 2013-01-05   NaN      110    C
# 2013-01-06   NaN      210    A
# 2013-01-07   1.0      130    F

# %%
pivot = pd.pivot_table(df_inner,index=['city'],values=['price'],columns\
                       =['size'],aggfunc=[len,np.sum],fill_value=0,\
                       margins=True)

# %%
pivot
# Out:
#             len                   sum
#           price                 price
# size          A  B  C  F  All       A       B     C     F      All
# city
# beijing       1  0  0  1  2.0  1200.0     0.0     0  4432   5632.0
# guangzhou     1  0  0  0  1.0  2133.0     0.0     0     0   2133.0
# shanghai      1  1  0  0  2.0  3299.5  3299.5     0     0   6599.0
# shenzhen      0  0  1  0  1.0     0.0     0.0  5433     0   5433.0
# All           3  1  1  1  6.0  6632.5  3299.5  5433  4432  19797.0

# %%
df_inner.sample(3)
# Out:
#                 city category-size  age   price  gender  m-point pay group  \
# date
# 2013-01-02   beijing         100-A   23  1200.0    male       10   y   low
# 2013-01-03  shanghai         100-B   44  3299.5  female       11   n  high
# 2013-01-05  shenzhen         110-C   32  5433.0  female      123   n  high
#
#             sign category size
# date
# 2013-01-02   NaN      100    A
# 2013-01-03   NaN      100    B
# 2013-01-05   NaN      110    C

# %%
df_inner.sample(2,weights=[0,0,0,0,0.5,0.5])
# Out:
#                 city category-size  age   price  gender  m-point pay group  \
# date
# 2013-01-06  shanghai         210-A   34  3299.5    male       42   y  high
# 2013-01-07   beijing         130-F   32  4432.0  female      213   y  high
#
#             sign category size
# date
# 2013-01-06   NaN      210    A
# 2013-01-07   1.0      130    F

# %%
df_inner.sample(6,replace=False)
# Out:
#                  city category-size  age   price  gender  m-point pay group  \
# date
# 2013-01-02    beijing         100-A   23  1200.0    male       10   y   low
# 2013-01-04  guangzhou         120-A   54  2133.0    male       11   y   low
# 2013-01-07    beijing         130-F   32  4432.0  female      213   y  high
# 2013-01-03   shanghai         100-B   44  3299.5  female       11   n  high
# 2013-01-05   shenzhen         110-C   32  5433.0  female      123   n  high
# 2013-01-06   shanghai         210-A   34  3299.5    male       42   y  high
#
#             sign category size
# date
# 2013-01-02   NaN      100    A
# 2013-01-04   NaN      120    A
# 2013-01-07   1.0      130    F
# 2013-01-03   NaN      100    B
# 2013-01-05   NaN      110    C
# 2013-01-06   NaN      210    A

# %%
df_inner.sample(6,replace=True)
# Out:
#                  city category-size  age   price  gender  m-point pay group  \
# date
# 2013-01-04  guangzhou         120-A   54  2133.0    male       11   y   low
# 2013-01-02    beijing         100-A   23  1200.0    male       10   y   low
# 2013-01-02    beijing         100-A   23  1200.0    male       10   y   low
# 2013-01-05   shenzhen         110-C   32  5433.0  female      123   n  high
# 2013-01-06   shanghai         210-A   34  3299.5    male       42   y  high
# 2013-01-06   shanghai         210-A   34  3299.5    male       42   y  high
#
#             sign category size
# date
# 2013-01-04   NaN      120    A
# 2013-01-02   NaN      100    A
# 2013-01-02   NaN      100    A
# 2013-01-05   NaN      110    C
# 2013-01-06   NaN      210    A
# 2013-01-06   NaN      210    A

# %%
df_inner.describe().round(2).T
# Out:
#          count     mean      std     min      25%     50%      75%     max
# age        6.0    36.50    10.88    23.0    32.00    33.0    41.50    54.0
# price      6.0  3299.50  1523.35  1200.0  2424.62  3299.5  4148.88  5433.0
# m-point    6.0    68.33    83.17    10.0    11.00    26.5   102.75   213.0
# sign       1.0     1.00      NaN     1.0     1.00     1.0     1.00     1.0

# %%
df_inner['price'].std()
# Out:
# 1523.3516337339847

# %%
df_inner.price.std()
# Out:
# 1523.3516337339847

# %%
df_inner.std()
# Out:
# age          10.876580
# price      1523.351634
# m-point      83.171309
# sign               NaN
# dtype: float64

# %%
df_inner.cov()
# Out:
#             age      price       m-point  sign
# age       118.3    -1353.5   -295.400000   NaN
# price   -1353.5  2320600.2  93963.300000   NaN
# m-point  -295.4    93963.3   6917.466667   NaN
# sign        NaN        NaN           NaN   NaN

# %%
df_inner['price'].cov(df_inner['m-point'])
# Out:
# 93963.3

# %%
df_inner['price'].corr(df_inner['m-point'])
# Out:
# 0.7416253403103628

# %%
df_inner.corr()
# Out:
#               age     price   m-point  sign
# age      1.000000 -0.081689 -0.326546   NaN
# price   -0.081689  1.000000  0.741625   NaN
# m-point -0.326546  0.741625  1.000000   NaN
# sign          NaN       NaN       NaN   NaN

# %%
df_inner.to_csv("Excel_to_Python.csv")

# %%
df_inner.to_Excel("Excel_to_Python",sheet_name="bluewhale_cc")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-108-c29ca691cdbd> in <module>()
# ----> 1 df_inner.to_Excel("Excel_to_Python",sheet_name="bluewhale_cc")
#
# E:\programfiles\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'to_Excel'
