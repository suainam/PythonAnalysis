# %% [markdown]
# # 1 什么是网络爬虫
# ## 1.1 数据来源
#
# + 企业生产数据、数据管理咨询公司、政府/机构等公开数据、第三方数据平台购买、爬虫爬取
# + 百度指数、微指数、国家数据、世界银行数据、Nasdaq、Undata、艾融、麦肯锡等
# + 数据堂、贵阳大数据交易所
#
# ## 1.2 爬虫实例
# 1. 搜索引擎。百度、谷歌、雅虎等
# 2. 抓取其他网站信息。伯乐在线，抓取其他网站的新闻等
# 3. 购物插件。惠惠购物助手，谷歌、ios、安卓等购物插件
# 4. 数据分析与研究，数据报告等。数据冰山、知乎专栏
# 5. 抢票软件等
#
# ## 1.3 网络爬虫
# 1. 一个模拟人类请求网站行为的程序，可以自动请求网页、并把数据抓取下来，然后使用一定的规则提取有价值的数据
# 2. [百度百科](https://baike.baidu.com/item/%E7%BD%91%E7%BB%9C%E7%88%AC%E8%99%AB/5162711?fr=aladdin)
#
# ## 1.4 爬虫的分类
# + 通用爬虫：搜索引擎抓取系统（百度、谷歌、搜狗等）的重要组成部分，主要是将互联网上的网页下载到本地，形成一个互联网内容的镜像备份
# + 聚焦爬虫：面向特定需求的一种网络爬虫程序，他与通用爬虫的区别在于：聚焦爬虫在实施网页抓取的时候会对内容进行筛选和处理，尽量保证只抓取与需求相关的网页信息
#
# ## 1.5 爬虫的工具，为什么使用Python
# 1. PHP：对多线程、异步支持不是很好，并发处理能力弱
# 2. Java：本身笨重，代码量大，重构成本比较高
# 3. C/C++：运行效率高，但学习和开发成本高
# 4. Python：代码简洁，开发效率高，支持的模块多。相关的HTTP请求模块和HTML解析模块非常丰富，还有Scrapy和Scrapy-redis框架让我们开发爬虫变得异常简单
#
# ## 1.6 准备工具
# 1. Python3.6开发环境
# 2. Pycharm 2017 professional版
# 3. 虚拟环境。virtualenv/virtualenvwrapper
# 2. HTTP协议和Chrome抓包工具
#
# ## 1.7 什么是http和https协议
# 1. Http协议：超文本传输协议，端口是80
# 2. HTTPS：HTTP的加密版本，加入了SSL协议，端口是443
#
# ## 1.8 爬虫的基本流程
#
# + 发送请求，request
# + 浏览器响应，response
# + 解析响应，xpath、正则等
# + 存储数据，存储到本地
#
# 1. 用户在浏览器输入网址并回车，浏览器会向HTTP服务器发送HTTP请求。HTTP请求主要分为“Get”和“Post”方法
# 2. 比如我们输入：[百度首页](http://www.baidu.com)，浏览器会发送1个Request请求去获取百度首页的html文件，服务器把Request文件对象发送回浏览器
# 3. 浏览器分析Request中的html文件，发现其中引用的其他文件，并自动再次发送Request去获取相关去房间
# 4. 当所有文件都下载成功后，网页会根据html语法结构，完整显示。
#
# ## 1.9 URL详解
# - URL：uniform resource locator
# - 一般由以下几部分组成：
# - scheme://host:port/path/?query-string=xxx#anchor
#     - scheme：网络协议，http、https、ftp等协议
#     - host：主机名，域名，如www.baidu.com
#     - port：端口
#     - path：查找路径
#     - query-string：查询字符串
#     - anchor：锚点。后台一般不用管，前段用来做页面定位
#     - 在浏览器中除英文字母，数字和部分符号外， 其他的全部使用百分号+十六进制进行编码（比如中文、特殊字符等）
#
# ## 1.9.1 常用的请求方法
# 1. 在http协议中，定义了8种请求方法，其中主要常用的：get、post请求
# 2. get请求：一般情况下，只从服务器获取数据下来，并不会对服务器资源产生任何影响的时候会使用get请求
# 3. post请求：向服务器发送数据（登录）、上传文件等，会对服务器资源产生影响的时候会使用post请求
# 部分网站和服务为了反爬虫，可能会将请求进行调换。
# - eg. 拉勾网将get变换成post请求
#
# ### 1.9.2 请求头的常见参数
# 1. 在HTTP协议中，向服务器发送一个情况，数据分为3部分：
# - 第1个是 把数据放在url中，
# - 第2个是 把数据放在body中（在post请求中）
# - 第3个是 把数据放在head中
# 2. user-agent：浏览器名称。爬虫的默认是Python，服务器一般会拒绝，需要手动设置。
# 3. referer：表明当前请求是从哪个url过来的，这个一般也是用来反爬虫的，如果不是从指定页面过来的，那么就不做相关的响应。
# 4. cookie：HTTP协议是无状态的，也就是同一个人发送了两次请求。服务器没有能力知道这两个请求是否来自同一个人，因此这是就用cookie来做表示。一般如果想要做登陆后才能访问的网站，那么就需要发送cookie信息了。
#
# #### 1.9.2.1 常见响应状态码
# - 200：请求正常，服务器正常的返回数据。只能表明请求过程是正常的。但是数据是否正确，需要看实际情况（比如服务器伪装）
# - 301：永久重定向，比如www.jingdong.com 到www.jd.com
# - 302：临时重定向，访问需要登录的网站，就会重定向到登录页面
# - 400：请求url错误
# - 403：服务器拒绝访问，权限不够
# - 500：服务器内部错误
#
# ### 1.9.2.2 Chrome抓包工具
# - Chrome 开发者选项，F12 或 右键-检查，易用方便。

# %% [markdown]
# # 2 网络请求
# ## 2.1 Urllib库
#
# + urllib是python中的内置的基本网络请求库。
#     + 可以模拟浏览器的行为，向指定的服务器发送1个请求，并可以保存服务器返回的数据。默认已经编码了，所以不能出现中文
# + request下面的urlopen函数
#     + 在python3 的urllib库中，所有和网络请求的相关方法，都集中在urllib.request 模块下面

# %%
from urllib import request

# %%
resp = request.urlopen('http://httpbin.org/get')

# %%
type(resp)
# 是一个类文件句柄的对象
# Out:
# http.client.HTTPResponse

# %%
resp.getcode()
# Out:
# 200

# %%
print(resp.read().decode('utf-8'))
# Out:
# {
#   "args": {},
#   "headers": {
#     "Accept-Encoding": "identity",
#     "Connection": "close",
#     "Host": "httpbin.org",
#     "User-Agent": "Python-urllib/3.6"
#   },
#   "origin": "223.73.197.86",
#   "url": "http://httpbin.org/get"
# }

# %%
print(dir(resp))
# Out:
# ['__abstractmethods__', '__class__', '__del__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__next__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_abc_cache', '_abc_negative_cache', '_abc_negative_cache_version', '_abc_registry', '_checkClosed', '_checkReadable', '_checkSeekable', '_checkWritable', '_check_close', '_close_conn', '_get_chunk_left', '_method', '_peek_chunked', '_read1_chunked', '_read_and_discard_trailer', '_read_next_chunk_size', '_read_status', '_readall_chunked', '_readinto_chunked', '_safe_read', '_safe_readinto', 'begin', 'chunk_left', 'chunked', 'close', 'closed', 'code', 'debuglevel', 'detach', 'fileno', 'flush', 'fp', 'getcode', 'getheader', 'getheaders', 'geturl', 'headers', 'info', 'isatty', 'isc
# ...

# %% [markdown]
# + request下面的urlretrieve 函数
#     + 将网页上的文件保存到本地

# %%
picture_lb = 'https://timgsa.baidu.com/timg?image&quality=80&size=b9999_10000&sec=1537381646487&di=52cc0e2b94732725a2bfb9cd9077a781&imgtype=0&src=http%3A%2F%2Fimg.eeyy.com%2Fuploadfile%2F2017%2F0424%2F20170424031628110.jpg'

# %%
request.urlretrieve(picture_lb,'baidu_lb.jpg')
# Out:
# ('baidu_lb.jpg', <http.client.HTTPMessage at 0x1eb871ca710>)

# %% [markdown]
# + parse下面的urlencode 函数
#     + 字典数据转换为url编码的数据，urllib中默认已经编码了，所以不能出现中文

# %%
from urllib import parse
data = {'name':'爬虫数据','greet':'Hello World','age':90}
qs = parse.urlencode(data)
print(qs)
# Out:
# name=%E7%88%AC%E8%99%AB%E6%95%B0%E6%8D%AE&greet=Hello+World&age=90

# %%
from urllib import request, parse
data = {'wd':'刘德华'}
parse = parse.urlencode(data)
resp = request.urlopen('http://www.baidu.com/s?'+ parse)
print(resp.read())
# Out:
# b'<!DOCTYPE html>\n<!--STATUS OK-->\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\t\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\n\n\n<html>\n\t<head>\n\t\t\n\t\t<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n\t\t<meta http-equiv="content-type" content="text/html;charset=utf-8">\n\t\t<meta content="always" name="referrer">\n        <meta name="theme-color" content="#2932e1">\n        <link rel="shortcut icon" href="/favicon.ico" type="image/x-icon" />\n        <link rel="icon" sizes="any" mask href="//www.baidu.com/img/baidu_85beaf5496f291521eb75ba38eacbd87.svg">\n        <link rel="search" type="application/opensearchdescription+xml" href="/content-search.xml" title="\xe7\x99\xbe\xe5\xba\xa6\xe6\x90\x9c\xe7\xb4\xa2" />\n\t\t\n\t\t\n<title>\xe5\x88\x98\xe5\xbe\xb7\xe5\x8d\x8e_\xe7\x9
# ...

# %%
from urllib import parse
data = {'name':'爬虫数据','greet':'Hello World','age':90}
qs = parse.urlencode(data)
result = parse.parse_qs(qs)
print(result)
# Out:
# {'name': ['爬虫数据'], 'greet': ['Hello World'], 'age': ['90']}

# %% [markdown]
# + parse下面的urlparse和urlsplit函数
#     + urlparse 比 urlsplit 多了params的属性。
#     + params主要用在s?之间，比如's:Hello?'，使用urlparse可以获得params，即Hello

# %%
url = 'http://www.baidu.com/s?wd=python&username=abc#1'

# %%
result = parse.urlparse(url)
print(result,type(result),sep='\n')
# Out:
# ParseResult(scheme='http', netloc='www.baidu.com', path='/s', params='', query='wd=python&username=abc', fragment='1')
# <class 'urllib.parse.ParseResult'>

# %%
print(result.scheme, result.netloc, result.path, result.params, result.query, sep='\n')
# Out:
# http
# www.baidu.com
# /s
#
# wd=python&username=abc

# %%
result_ = parse.urlsplit(url)
print(result)
# Out:
# ParseResult(scheme='http', netloc='www.baidu.com', path='/s', params='', query='wd=python&username=abc', fragment='1')

# %%
print(result_.scheme, result_.netloc, result_.path, 
      result_.query, sep='\n')
# Out:
# http
# www.baidu.com
# /s
# wd=python&username=abc

# %%
# 编写一个可以返回查询‘python urllib 中文’的百度网页
from urllib import request, parse
# 获得用户的输入
data['wd'] = input()
url_before = 'http://www.baidu.com/s?'
# 使用parse进行编码并组装成url
url = url_before + parse.urlencode(data)
# 使用request下的urlopen和urlretrieve进行url的捕获和保存
resp = request.urlopen(url)
request.urlretrieve(url,'Python的百度搜索结果.html')
# Out:
# python
# ('Python的百度搜索结果.html', <http.client.HTTPMessage at 0x1eb871dda20>)

# %%
# 使用parse下面的urlparse和urlsplit对url进行拆分
print(parse.urlsplit(url), parse.urlparse(url), sep='\n')
# Out:
# SplitResult(scheme='http', netloc='www.baidu.com', path='/s', query='wd=python', fragment='')
# ParseResult(scheme='http', netloc='www.baidu.com', path='/s', params='', query='wd=python', fragment='')

# %%
# 使用parse下面的urlencode和urlparse_qs进行编码和解码
ps = parse.urlencode(data)
ps_b = parse.parse_qs(ps)
print(ps, ps_b, sep='\n')
# Out:
# wd=python
# {'wd': ['python']}

# %% [markdown]
# ### request的Request, 添加请求头
# + 以拉勾网为例，如果不添加请求头，会返回假数据
# + 然后通过Ajax进行嵌入，真实的是post请求的js文件
# + 找到PositonAjax的js文件，然后对headers添加Referer，data属性，并使用post请求，获取真实的网页
# ```python
# req = request.Request(url, headers=headers)
# resp = request.urlopen(req)
# resp.read().decode('utf-8')
# ```

# %%
from urllib import request
from urllib import parse
jsurl = 'https://www.lagou.com/jobs/positionAjax.json?city=%E5%B9%BF%E5%B7%9E&needAddtionalResult=false'
headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 Safari/537.36',
    'Referer':'https://www.lagou.com/jobs/list_python%E7%88%AC%E8%99%AB?oquery=%E7%88%AC%E8%99%AB&fromSearch=true&labelWords=relative&city=%E5%B9%BF%E5%B7%9E'
}
data = {
    'first':'true',
    'pn':1,
    'kd':'python爬虫'
}

datab = parse.urlencode(data).encode('utf-8')
req1 = request.Request(jsurl, headers=headers, data=datab, method='POST')
resp = request.urlopen(req1)
# print(resp.read().decode('utf-8'))
resp.getcode()
# Out:
# 200

# %% [markdown]
# ### ProxyHandler处理器（代理设置）
#
# + 目的：防止因为1个ip地址过多访问被封ip
# + 原理：在请求目的网站之前，先请求代理服务器，然后让代理服务器去请求目的网站，代理服务器拿到nudity网站的数据后，在转发给我们的代码
#     + 使用“urllib.request.ProxyHandler”，传入一个代理，字典的形式，依赖于代理服务器能够接受的类型，key一般是“http”或者“https”,值是“ip:port”
#     + 使用上一步创建的Handler，以及“urllib.request.built_opener”创建一个“opener”
#     + 使用上一步创建的“opener”，使用open函数，发起请求
# + 代理网站
#     + 西刺代理：http://www.xicidaili.com/
#     + 快代理：https://www.kuaidaili.com/free/
#     + 代理运：http://www.dailiyun.com

# %%
from urllib import request
from urllib import parse
getip_url="http://httpbin.org/ip"

# %%
handler = request.ProxyHandler({"http":"58.62.238.150:58479"})
opener = request.build_opener(handler)
resp = opener.open(getip_url)
print(resp.read())
# Out:
# b'{\n  "origin": "58.62.238.150"\n}\n'

# %% [markdown]
# ### Cookie
#
# + 身份辨识
# + 一般不超过4kb，有过期的时间
# + cookie的格式
# ```python
# Set-Cookie: NAME=VALUE；Expires/Max-age=DATE；Path=PATH；Domain=DOMAIN_NAME；SECURE
# ```
# + 参数意义：
#     + NAME：cookie的名字。
#     + VALUE：cookie的值。
#     + Expires：cookie的过期时间。
#     + Path：cookie作用的路径。
#     + Domain：cookie作用的域名。
#     + SECURE：是否只在https协议下起作用。

# %% [markdown]
# + 使用cookie实现登录来请求网页
# + 示例网页：人人网
#     + url = 'http://www.renren.com/880151247/profile'

# %%
# 没有cookie，返回了登录页面
from urllib import request
headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 Safari/537.36'
}
dpurl = 'http://www.renren.com/880151247/profile'

req = request.Request(dpurl, headers=headers)
resp = request.urlopen(req)
# print(resp.read().decode('utf-8'))
print(resp.getcode())
# Out:
# 200

# %% [markdown]
# + 查看网页，发现Headers里面有Cooike信息，复制并添加到headers
# ```python
# headers = {
#     'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 Safari/537.36',
#     'Cookie':'anonymid=jmyqzv5895gsmx; depovince=GW; _r01_=1; JSESSIONID=abcWKAa_hTYQR9lJ8jozw; ick_login=16ae7464-97f6-482e-9629-8ea1357c0a0e; t=34e92d69086390e51ed7442e4c0d772d8; societyguester=34e92d69086390e51ed7442e4c0d772d8; id=968277398; xnsid=b1d7ed42; jebecookies=88e9bdc3-8862-484e-b788-ffba96f0ad0c|||||; ver=7.0; loginfrom=null; wp_fold=0'
# }
# with open('dpurl.html', 'w', encoding='utf-8') as fp:
#     fp.write(resp.read().decode('utf-8'))
# ```
# + 再次请求，得到正确的页面

# %% [markdown]
# + http.cookiejar模块

# %%
from urllib import request, parse
from http.cookiejar import CookieJar

headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 Safari/537.36'
}

def built_opener():
    cookiejar = CookieJar()
    handler = request.HTTPCookieProcessor(cookiejar)
    opener = request.build_opener(handler)
    return opener

def login_url(opener):
    data = {'email':'970138074@qq.com', 'password':'pythonspider'}
    data = parse.urlencode(data).encode('utf-8')
    req = request.Request(log_url, headers=headers, data=data)
    opener.open(req)

def visit_profile(opener):
    req = request.Request(dp_url, headers=headers)
    dp_html = opener.open(req)
    with open('./dp.html', 'w', encoding='utf-8') as fp:
        fp.write(dp_html.read().decode('utf-8'))
    
if __name__ == '__main__':
    log_url = 'http://www.renren.com/PLogin.do'
    dp_url = 'http://www.renren.com/880151247/profile'
    
    opener = built_opener()
    login_url(opener)
    visit_profile(opener)

# %% [markdown]
# + 保存cookie到本地

# %%
# 保存百度的cookie
from urllib import request, parse
from http.cookiejar import MozillaCookieJar

cookiejar = MozillaCookieJar('mcookie.txt')
handler = request.HTTPCookieProcessor(cookiejar)
opener = request.build_opener(handler)

resp = opener.open('http://www.baidu.com/')
cookiejar.save()

# %%
# 保存httpbin的自定义cookie
from urllib import request, parse
from http.cookiejar import MozillaCookieJar

cookiejar = MozillaCookieJar('mcookie_text.txt')
handler = request.HTTPCookieProcessor(cookiejar)
opener = request.build_opener(handler)

resp = opener.open('http://httpbin.org/cookies/set?course=abc')
cookiejar.save(ignore_discard=True)

# %%
# 保存并读取httpbin的自定义cookie
from urllib import request, parse
from http.cookiejar import MozillaCookieJar

cookiejar = MozillaCookieJar('mcookie_text.txt')
cookiejar.load(ignore_discard=True)
handler = request.HTTPCookieProcessor(cookiejar)
opener = request.build_opener(handler)

resp = opener.open('http://httpbin.org/cookies/set?course=abc')
for cookie in cookiejar:
    print(cookie)
# Out:
# <Cookie course=abc for httpbin.org/>

# %% [markdown]
# ### 请求、响应、解析
#
# + 发送并响应：Requests库, get的请求方法，headers的使用
# + 解析：Xpath, BeautifulSoup, 正则表达式

# %%
import requests

# %%
# url为测试网站
url = 'http://httpbin.org/get'
response = requests.get(url)
print(response.text)
# Out:
# {
#   "args": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Connection": "close",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.18.4"
#   },
#   "origin": "223.73.197.86",
#   "url": "http://httpbin.org/get"
# }

# %%
# 定制请求头
headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 Safari/537.36'
}
responseh = requests.get(url, headers=headers)
print(responseh.text)
# Out:
# {
#   "args": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Connection": "close",
#     "Host": "httpbin.org",
#     "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 Safari/537.36"
#   },
#   "origin": "223.73.197.86",
#   "url": "http://httpbin.org/get"
# }

# %%
print(responseh.status_code)
# Out:
# 200

# %% [markdown]
# + 数据提取-xpath-节点关系
#     + 父：每个元素以及属性都有一个父
#     + 子：元素节点可有0个、1个或多个
#     + 同胞：拥有相通的父节点
#     + 先辈：某节点的父、父的父，等等
#     + 后代：某个节点的子，子的子等

# %% [markdown]
# + XPATH常用路径表达式
#     + / : 选中文档的根(root)
#     + . : 选中当前节点
#     + .. : 选中当前节点的父节点
#     + ELEMENT：选中子节点中所有ELEMENT元素的节点
#     + //ELEMENT：选中后代节点中所有ELEMENT元素的节点
#     + \* ：选中所有元素子节点
#     + text() : 选中所有文本子节点
#     + @ATTR ：选中名为ATTR的属性节点
#     + @* : 选中所有属性节点
#     + [谓语] ：用来查找某个特定的节点，或者包含某个特定值的节点。是从1开始的
#         + /bookstore/book[1]	选取bookstore下的第一个子元素
#         + /bookstore/book[last()]	选取bookstore下的倒数第二个book元素。
#         + bookstore/book[position()<3]	选取bookstore下前面两个子元素。
#         + //book[@price]	选取拥有price属性的book元素
#         + //book[@price=10]	选取所有属性price等于10的book元素
#     + contains, 有时候某个属性中包含了多个值，
# ```python
# //dl[contains(@class, 'job')]
# ```
#     + 运算符、通配符\*

# %%
from lxml import etree
import requests

# %%
url = 'http://lol.duowan.com/hero/'
headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 Safari/537.36'
}
rep = requests.get(url, headers=headers)
if rep.status_code==200:
    html = etree.HTML(rep.text)
    hero_names=html.xpath('//div[@class="champion_name"]/text()')
    print(hero_names)
# Out:
# ['凯隐', '洛', '霞', '卡蜜尔', '艾翁', '克烈', '塔莉垭', '索尔', '烬', '俄洛伊', '千珏', '塔姆', '艾克', '巴德', '雷克赛', '卡莉丝塔', '阿兹尔', '纳尔', '布隆', '维克兹', '亚索', '金克丝', '卢锡安', '亚托克斯', '丽桑卓', '扎克', '奎因', '锤石', '蔚', '娜美', '劫', '伊莉丝', "卡'兹克", '辛德拉', '雷恩加尔', '黛安娜', '婕拉', '杰斯', '德莱文', '德莱厄斯', '赫卡里姆', '韦鲁斯', '璐璐', '菲奥娜', '诺提勒斯', '瑟庄妮', '吉格斯', '维克托', '阿狸', '沃利贝尔', '菲兹', '特朗德尔', '拉克丝', '布兰德', '希瓦娜', '格雷福斯', '泽拉斯', '图奇', '锐雯', '泰隆', '斯卡纳', '孙悟空', '蕾欧娜', '约里克', '瑞兹', '卡特琳娜', '裟娜', '斯维因', '乐芙兰', '艾瑞莉娅', '卡西奥佩娅', '凯特琳', '雷克顿', '卡尔玛', '茂凯', '嘉文四世', '魔腾', '李青', '兰博', '薇恩', '奥莉安娜', "科'加斯", '努努', '阿木木', '维迦', '辛吉德', '泰达米尔', '蒙多', '普朗克', '墨菲特', '希维尔', '费德提克', '凯尔', '艾尼维亚', '提莫', '艾希', '安妮', '崔丝塔娜', '贾克斯', '易', '库奇', '阿利斯塔', '布里茨', '索拉卡', '内瑟斯', '沃里克', '莫甘娜', '拉莫斯', '卡萨丁', '赛恩', '塔里克', '迦娜', '基兰', '崔斯特', '伊芙琳', '卡尔萨斯', '萨科', '黑默丁格', '阿卡丽', '乌迪尔', '盖伦', '凯南', "克格'莫", '玛尔扎哈', '莫德凯撒', '奈德丽', '伊泽瑞尔', '古拉加斯', '奥拉夫', '潘森', '波比', '慎', '赵信', '弗拉基米尔', '加里奥', '厄加特', '厄运小姐']

# %%
hero_url = html.xpath('//ul[@id="champion_list"]/li/a/@href')
print(hero_url)
# Out:
# ['http://lol.duowan.com/kayn/', 'http://lol.duowan.com/rakan/', 'http://lol.duowan.com/xayah/', 'http://lol.duowan.com/camille/', 'http://lol.duowan.com/ivern/', 'http://lol.duowan.com/ivern/', 'http://lol.duowan.com/taliyah/', 'http://lol.duowan.com/sol/', 'http://lol.duowan.com/jhin/', 'http://lol.duowan.com/illaoi/', 'http://lol.duowan.com/Kindred/', 'http://lol.duowan.com/tahmkench/', 'http://lol.duowan.com/ekko/', 'http://lol.duowan.com/bard/', 'http://lol.duowan.com/reksai/', 'http://lol.duowan.com/kalista/', 'http://lol.duowan.com/azir/', 'http://lol.duowan.com/gnar/', 'http://lol.duowan.com/braum/', 'http://lol.duowan.com/velkoz/', 'http://lol.duowan.com/yasuo/', ' http://lol.duowan.com/jinx/', ' http://lol.duowan.com/lucian/', 'http://lol.duowan.com/aatrox/', 'http://lol.duowan.com/lissandra/', 'http://lol.duowan.com/zac/', 'http://lol.duowan.com/quinn/', 'http://lol.duowan.com/thresh/', 'http://lol.duowan.com/vi/', 'http://lol.duowan.com/nami/', 'http://lol.duowan.com/zed/'
# ...

# %%
url2='http://lol.duowan.com/fiora/'
resp1 = requests.get(url2,headers=headers)
# print(resp1.text)
html2 = etree.HTML(resp1.text)
hero_img = html2.xpath('//ul[@class="ui-slide__content"]//img/@src')
print(hero_img)
# Out:
# ['http://img4.dwstatic.com/lol/1512/315328877895/1451373686871.jpg', 'http://img3.dwstatic.com/lol/1512/315328877895/1451373694187.jpg', 'http://img5.dwstatic.com/lol/1512/315328877895/1451373701469.jpg', 'http://img5.dwstatic.com/lol/1512/315328877895/1451373710269.jpg', 'http://img2.dwstatic.com/lol/1512/315328877895/1451373717816.jpg']

# %% [markdown]
# + 数据存储
#     + 文本：纯文本、json、scv等
#     + 数据库：MySQL、Oracle；MongoDB、Redis等
#     + 二进制文件：图片等
# + 案例总结
#     + 确定目标：每个英雄对应的壁纸
#     + 分析目标
#         + 起始网页
#         + 英雄详情
#         + 英雄壁纸
#         + 数据位置
#         + 英雄名称
#         + 英雄壁纸

# %% [markdown]
# ### 任务
# + 需要自动根据英雄的信息进行英雄详细页面中图片的爬取

# %%
l1 = 'abdcf'
l2 = '12344'
c = dict(zip(l1,l2))

# %%
len(c.keys())
# Out:
# 5

# %%
# ?zip
# Out:
# Init signature: zip(self, /, *args, **kwargs)
# Docstring:
# zip(iter1 [,iter2 [...]]) --> zip object
#
# Return a zip object whose .__next__() method returns a tuple where
# the i-th element comes from the i-th iterable argument.  The .__next__()
# method continues until the shortest iterable in the argument sequence
# is exhausted and then it raises StopIteration.
# Type:           type

# %%
with open('./小案例/LOL/1.txt', 'w+') as f:
    f.write('测试')

# %%
import requests
from lxml import etree

headers = {
        'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 Safari/537.36'
    }
def get_heros_url(url):
    hero_htmls_resps = requests.get(url, headers=headers)
    hero_htmls = etree.HTML(hero_htmls_resps.text)
    hero_name = hero_htmls.xpath('//div[@class="champion_name"]/text()')
    hero_url = hero_htmls.xpath('//ul[@id="champion_list"]//a/@href')
    hero_infos = dict(zip(hero_name, hero_url))
    return hero_infos

def get_heros_img(hero_url):
    hero_img_resps = requests.get(hero_url, headers=headers)
    hero_info = etree.HTML(hero_img_resps.text)
    hero_imgs = hero_info.xpath('//div[@class="hero-info"]//img[@alt="$title"]/@src')
    return hero_imgs

def store_hero_info(hero_info, hero_img_con):
    
    with open('./小案例/LOL/'+hero_info, 'wb') as f:
        f.write(hero_img_con)

def main():
    url = 'http://lol.duowan.com/hero/'
    
    dict_text = get_heros_url(url)
    count=0
    for hero_name, hero_url in dict_text.items():
        hero_imgs = get_heros_img(hero_url)
        count+=len(hero_imgs)
        for hero_img in hero_imgs:
            hero_img_con = requests.get(hero_img, headers=headers)
            hero_img_con = hero_img_con.content
            hero_info = hero_name + hero_img[-8:]
            store_hero_info(hero_info, hero_img_con)
            
    print('一共有{}个英雄，下载了{}个英雄的壁纸'.format(len(dict_text.keys), count))
    
if __name__=='__main__':
    main()

# %% [markdown]
# ## 2.2 requests库
# + 虽然Python的标准库中,urllib模块已经包含了平常我们使用的大多数功能，但是它的 API 使用起来让人感觉不太好，而 Requests宣传是 “HTTP for Humans”，说明使用更简洁方便。
# + 安装和文档地址：
#     + 利用pip可以非常方便的安装：
#     + pip install requests
#
# - 中文文档：http://docs.python-requests.org/zh_CN/latest/index.html
# - github地址：https://github.com/requests/requests
#
# #### 发送GET请求：
# + 最简单的发送get请求就是通过requests.get来调用：
# ```python
# response = requests.get("http://www.baidu.com/")
# ```
#
# ##### 添加headers和查询参数：
# + 如果想添加 headers，可以传入headers参数来增加请求头中的headers信息。如果要将参数放在url中传递，可以利用 params 参数。相关示例代码如下：
#
# ```python
#  import requests
#
#  kw = {'wd':'中国'}
#
#  headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.99 Safari/537.36"}
#
#  # params 接收一个字典或者字符串的查询参数，字典类型自动转换为url编码，不需要urlencode()
#  response = requests.get("http://www.baidu.com/s", params = kw, headers = headers)
#
#  # 查看响应内容，response.text 返回的是Unicode格式的数据
#  print(response.text)
#
#  # 查看响应内容，response.content返回的字节流数据
#  print(response.content)
#
#  # 查看完整url地址
#  print(response.url)
#
#  # 查看响应头部字符编码
#  print(response.encoding)
#
#  # 查看响应码
#  print(response.status_code)
# ```

# %%
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.99 Safari/537.36"}
kw = {
'wd':'中国'
}
url = 'http://www.baidu.com/s'
resp = requests.get(url, params=kw, headers=headers)
with open('百度搜索_中国.html','w',encoding='utf-8') as fp:
    fp.write(resp.content.decode('utf-8'))

# %%
print(resp.url)
# Out:
# http://www.baidu.com/s?wd=%E4%B8%AD%E5%9B%BD

# %% [markdown]
# #### 发送POST请求：
#
# + 最基本的POST请求可以使用post方法：
# ```python
# response = requests.post("http://www.baidu.com/",data=data)
# ```
#
# #### 传入data数据：
#
# + 这时候就不要再使用urlencode进行编码了，直接传入一个字典进去就可以了。比如请求拉勾网的数据的代码：

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.99 Safari/537.36',
    'Referer':'https://www.lagou.com/jobs/list_python%E7%88%AC%E8%99%AB?oquery=%E7%88%AC%E8%99%AB&fromSearch=true&labelWords=relative&city=%E5%B9%BF%E5%B7%9E'
}
lg_url = 'https://www.lagou.com/jobs/positionAjax.json?city=%E5%B9%BF%E5%B7%9E&needAddtionalResult=false'

import requests, json

data = {
'first':'true',
'pn':1,
'kw':'python爬虫'}

resp = requests.post(lg_url, headers=headers, data=data)
print(resp.json())

# %% [markdown]
# #### 使用代理：
#
# + 使用requests添加代理也非常简单，只要在请求的方法中（比如get或者post）传递proxies参数就可以了。示例代码如下：

# %%
test_url = 'http://httpbin.org/get'
# proxy = {
# 'http':'58.62.238.150:58479'
# }

resp = requests.get(test_url)#, proxies=proxy)
print(resp.text)
# Out:
# {
#   "args": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Connection": "close",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.18.4"
#   },
#   "origin": "223.73.197.86",
#   "url": "http://httpbin.org/get"
# }

# %%
test_url = 'http://httpbin.org/get'
proxy = {
'http':'58.62.238.150:58479'
}

resp = requests.get(test_url, proxies=proxy)
print(resp.text)
# Out:
# {
#   "args": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Connection": "close",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.18.4"
#   },
#   "origin": "58.62.238.150",
#   "url": "http://httpbin.org/get"
# }

# %% [markdown]
# ### cookie：
# + 如果在一个响应中包含了cookie，那么可以利用cookies属性拿到这个返回的cookie值：

# %%
import requests
url = 'https://www.baidu.com'
resp = requests.get(url)
print(resp.cookies)
# Out:
# <RequestsCookieJar[<Cookie BDORZ=27315 for .baidu.com/>]>

# %%
resp.cookies.get_dict()
# Out:
# {'BDORZ': '27315'}

# %% [markdown]
# #### session：
#
# + 之前使用urllib库，是可以使用opener发送多个请求，多个请求之间是可以共享cookie的。那么如果使用requests，也要达到共享cookie的目的，那么可以使用requests库给我们提供的session对象。
# + **注意，这里的session不是web开发中的那个session，这个地方只是一个会话的对象而已。还是以登录人人网为例，使用requests来实现。**
# 示例代码如下：

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.99 Safari/537.36'}
log_url = 'http://www.renren.com/PLogin.do'
dp_url = 'http://www.renren.com/880151247/profile'

session = requests.Session()
data = {'email':'970138074@qq.com', 'password':'pythonspider'}
session.post(log_url, data=data, headers=headers)

resp = session.get(dp_url)
print(resp.status_code, resp.url)
# Out:
# 200 http://www.renren.com/880151247/profile

# %% [markdown]
# ### 处理不信任的SSL证书：
#
# + 对于已经被信任的SSL整数的网站，可以正常响应，比如:[https://www.baidu.com/](https://www.baidu.com/)
# + 如果无法正常响应，那么需要加'verify=False'

# %%
import requests
test_url = 'https://www.json.cn/'
resp = requests.get(test_url, verify=False)
print(resp.content.decode('utf-8'))

# %% [markdown]
# # 3 网页的解析
# ## 3.1 Xpath
#
# + xpath（XML Path Language）是一门在XML和HTML文档中查找信息的语言，可用来在XML和HTML文档中对元素和属性进行遍历。
# + Xpath开发工具
#     + chrome, xpath helper
#     + Firefox, Try xpath
#
# ## 3.2 Xpath语法，见2中
# ## 3.3 lxml的使用

# %%
text='''
<div id="home_cont" class="content">
    	<div class="maxwidth">
	    	<div class="left" id="home_l">
	    		<div class="left" id="home_ll">
	    			<form action="position.php">
	    				<div id="hsearch1">
			    			<input name="keywords" id="hsearch" t="请输入关键词" class="left"/>
			    			<input type="submit" id="hshearbut" value="" class="left pointer"/>
			    			<div class="clr"></div>
		    			</div>
		    		</form>
		    		<div id="hworkplace">
		    				<a href="position.php">全部</a>
		    					    				<a href="position.php?lid=2218">深圳</a>
		    					    				<a href="position.php?lid=2156">北京</a>
		    					    				<a href="position.php?lid=2175">上海</a>
		    					    				<a href="position.php?lid=2196">广州</a>
		    					    				<a href="position.php?lid=2268">成都</a>
		    					    				<a href="position.php?lid=2252">杭州</a>
		    					    				<a href="position.php?lid=2426">昆明</a>
		    					    				<a href="position.php?lid=33">美国</a>
		    					    				<a href="position.php?lid=2459">香港</a>
		    					    		</div>
		    		<div id="hzhiwei">
		    				<a href="position.php">全部</a>
		    					    				<a href="position.php?tid=87">技术类</a>
		    					    				<a href="position.php?tid=82">产品/项目类</a>
		    					    				<a href="position.php?tid=83">市场类</a>
		    					    				<a href="position.php?tid=81">设计类</a>
		    					    				<a href="position.php?tid=84">职能类</a>
		    					    				<a href="position.php?tid=85">内容编辑类</a>
		    					    				<a href="position.php?tid=86">客户服务类</a>
		    					    		</div>
	    		</div>
	    		<div class="right" id="home_lr" style="padding-top:26px;">
	    			<div>
	    				<div class="right">
	    					<a href="position.php">更多&gt;&gt;</a>
	    				</div>
	    				<div class="clr"></div>
	    			</div>
	    			<table id="hhotzw">
	    				    				<tr>
	    					<td>
	    						<a href="position_detail.php?id=44604" title="18796-Android开发工程师（深圳）">18796-Android开发工程师...</a>
	    					</td>
	    					<td align="right"><a href="position.php?lid=2218">深圳</a></td>
	    				</tr>
	    				    				<tr>
	    					<td>
	    						<a href="position_detail.php?id=44595" title="25926-游戏安全产品经理（深圳）">25926-游戏安全产品经理（...</a>
	    					</td>
	    					<td align="right"><a href="position.php?lid=2218">深圳</a></td>
	    				</tr>
	    				    				<tr>
	    					<td>
	    						<a href="position_detail.php?id=44575" title="SA-腾讯社交广告经营分析经理 （北京/深圳）">SA-腾讯社交广告经营分析...</a>
	    					</td>
	    					<td align="right"><a href="position.php?lid=2156">北京</a></td>
	    				</tr>
	    				    				<tr>
	    					<td>
	    						<a href="position_detail.php?id=44576" title="SA-腾讯社交广告SMB区域合作伙伴拓展经理--南区（深圳）">SA-腾讯社交广告SMB区...</a>
	    					</td>
	    					<td align="right"><a href="position.php?lid=2218">深圳</a></td>
	    				</tr>
	    				    				<tr>
	    					<td>
	    						<a href="position_detail.php?id=44578" title="CSIG16-基础架构工程师（北京）">CSIG16-基础架构工程师...</a>
	    					</td>
	    					<td align="right"><a href="position.php?lid=2156">北京</a></td>
	    				</tr>
	    				    				<tr>
	    					<td>
	    						<a href="position_detail.php?id=44559" title="18796-专项技术测试(深圳）">18796-专项技术测试(深圳）</a>
	    					</td>
	    					<td align="right"><a href="position.php?lid=2218">深圳</a></td>
	    				</tr>
	    				    				<tr>
	    					<td>
	    						<a href="position_detail.php?id=44560" title="19823-动画番剧制片人（北京）">19823-动画番剧制片人（北...</a>
	    					</td>
	    					<td align="right"><a href="position.php?lid=2156">北京</a></td>
	    				</tr>
	    				    				<tr>
	    					<td>
	    						<a href="position_detail.php?id=44562" title="18425-外汇高级运营经理">18425-外汇高级运营经理</a>
	    					</td>
	    					<td align="right"><a href="position.php?lid=2218">深圳</a></td>
	    				</tr>
	    				    				<tr>
	    					<td>
	    						<a href="position_detail.php?id=44551" title="HY6-互娱内容营销方向市场推广经理（郑州）">HY6-互娱内容营销方向市...</a>
	    					</td>
	    					<td align="right"><a href="position.php?lid=2393">太原</a></td>
	    				</tr>
	    				    				<tr>
	    					<td>
	    						<a href="position_detail.php?id=44537" title="21229-Android资深研发工程师（上海）">21229-Android资深研发工...</a>
	    					</td>
	    					<td align="right"><a href="position.php?lid=2175">上海</a></td>
	    				</tr>
	    				    			</table>
	    		</div>
	    		<div class="clr"></div>
	    	</div>
	    	<div class="right" id="home_r">
				<div id="hnews" style="padding-top:24px;">
					<div>
	    				<div class="right">
	    					<a href="news.php">更多&gt;&gt;</a>
	    				</div>
	    				<div class="clr"></div>
	    			</div>
					<div id="hnewsitems" class="square">
												<a href="news_detail.php?id=271" title="来，企业微信期待你的力量！">来，企业微信期待你的力量！</a>
												<a href="news_detail.php?id=270" title="登顶百国榜首，共创“吃鸡”盛宴 ">登顶百国榜首，共创“吃鸡”盛宴 </a>
												<a href="news_detail.php?id=269" title="微信游戏招兵买马！">微信游戏招兵买马！</a>
												<a href="news_detail.php?id=268" title="MIG2018年春季专场招聘会">MIG2018年春季专场招聘会</a>
												<a href="news_detail.php?id=267" title="腾讯SNG春季技术专场招聘会">腾讯SNG春季技术专场招聘会</a>
												<a href="news_detail.php?id=266" title="腾讯热招AI职位集锦">腾讯热招AI职位集锦</a>
												<a href="news_detail.php?id=265" title="诚邀众俠，仗剑江湖 ">诚邀众俠，仗剑江湖 </a>
												<a href="news_detail.php?id=264" title="《王者荣耀》全球版期待你的加入">《王者荣耀》全球版期待你的加入</a>
											</div>
					<div id="dians" class="textr">
													<a href="javascript:;" num="0" class="dian active">&nbsp;</a>
													<a href="javascript:;" num="2" class="dian">&nbsp;</a>
													<a href="javascript:;" num="4" class="dian">&nbsp;</a>
													<a href="javascript:;" num="6" class="dian">&nbsp;</a>
											</div>
					<div class="clr"></div>
				</div>
				<div id="hvideo" onclick="showHomeVideo('i01879zlatk');">
					<div id="videoshow">
						<a href="javascript:;"></a>
					</div>
				</div>
	    	</div>
	    	<div class="clr"></div>
	    </div>
	</div>'''

# %%
from lxml import etree
htmlElement = etree.HTML(text)
print(type(htmlElement))
# Out:
# <class 'lxml.etree._Element'>

# %%
gfhtmlElement = etree.tostring(htmlElement, encoding='utf-8').decode('utf-8')
print(gfhtmlElement)

# %%
# 如果格式不规范，那么需要制定html解析器
parser = etree.HTMLParser(encoding='utf-8')
htmlele = etree.parse('./Tencent.html', parser=parser)
# htmlele = etree.tostring(htmlele, encoding='utf-8').decode('utf-8')
# print(htmlele)

# %% [markdown]
# + 使用etree.HTMLParser()解析器来解析不规范的html代码

# %%
# 获取a标签的href中包含“positon_detail”的href属性
hrefs = htmlele.xpath('//a[contains(@href,"position_detail")]/@href')
for href in hrefs:
    print(href)
# Out:
# position_detail.php?id=44604
# position_detail.php?id=44595
# position_detail.php?id=44575
# position_detail.php?id=44576
# position_detail.php?id=44578
# position_detail.php?id=44559
# position_detail.php?id=44560
# position_detail.php?id=44562
# position_detail.php?id=44551
# position_detail.php?id=44537

# %%
tds2nd = htmlele.xpath('//td[2]')[0]
print(etree.tostring(tds2nd, encoding='utf-8').decode('utf-8'))
# Out:
# <td align="right"><a href="position.php?lid=2218">深圳</a></td>&#13;

# %%
tds = htmlele.xpath('//td')
for td in tds:
    href = td.xpath('./a/@href')
    title = td.xpath('./a/text()')[0]
    print(href,title)
# Out:
# ['position_detail.php?id=44604'] 18796-Android开发工程师...
# ['position.php?lid=2218'] 深圳
# ['position_detail.php?id=44595'] 25926-游戏安全产品经理（...
# ['position.php?lid=2218'] 深圳
# ['position_detail.php?id=44575'] SA-腾讯社交广告经营分析...
# ['position.php?lid=2156'] 北京
# ['position_detail.php?id=44576'] SA-腾讯社交广告SMB区...
# ['position.php?lid=2218'] 深圳
# ['position_detail.php?id=44578'] CSIG16-基础架构工程师...
# ['position.php?lid=2156'] 北京
# ['position_detail.php?id=44559'] 18796-专项技术测试(深圳）
# ['position.php?lid=2218'] 深圳
# ['position_detail.php?id=44560'] 19823-动画番剧制片人（北...
# ['position.php?lid=2156'] 北京
# ['position_detail.php?id=44562'] 18425-外汇高级运营经理
# ['position.php?lid=2218'] 深圳
# ['position_detail.php?id=44551'] HY6-互娱内容营销方向市...
# ['position.php?lid=2393'] 太原
# ['position_detail.php?id=44537'] 21229-Android资深研发工...
# ['position.php?lid=2175'] 上海

# %%
for td in tds:
    title = td.xpath('.//text()')
    print(title)
# Out:
# ['\r\n\t    \t\t\t\t\t\t', '18796-Android开发工程师...', '\r\n\t    \t\t\t\t\t']
# ['深圳']
# ['\r\n\t    \t\t\t\t\t\t', '25926-游戏安全产品经理（...', '\r\n\t    \t\t\t\t\t']
# ['深圳']
# ['\r\n\t    \t\t\t\t\t\t', 'SA-腾讯社交广告经营分析...', '\r\n\t    \t\t\t\t\t']
# ['北京']
# ['\r\n\t    \t\t\t\t\t\t', 'SA-腾讯社交广告SMB区...', '\r\n\t    \t\t\t\t\t']
# ['深圳']
# ['\r\n\t    \t\t\t\t\t\t', 'CSIG16-基础架构工程师...', '\r\n\t    \t\t\t\t\t']
# ['北京']
# ['\r\n\t    \t\t\t\t\t\t', '18796-专项技术测试(深圳）', '\r\n\t    \t\t\t\t\t']
# ['深圳']
# ['\r\n\t    \t\t\t\t\t\t', '19823-动画番剧制片人（北...', '\r\n\t    \t\t\t\t\t']
# ['北京']
# ['\r\n\t    \t\t\t\t\t\t', '18425-外汇高级运营经理', '\r\n\t    \t\t\t\t\t']
# ['深圳']
# ['\r\n\t    \t\t\t\t\t\t', 'HY6-互娱内容营销方向市...', '\r\n\t    \t\t\t\t\t']
# ['太原']
# ['\r\n\t    \t\t\t\t\t\t', '21229-Android资深研发工...', '\r\n\t    \t\t\t\t\t']
# ['上海']

# %% [markdown]
# ## 3.4 爬取豆瓣电影

# %%
import requests

headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 Safari/537.36',
    'Referer':'https://movie.douban.com/'
}
movie_douban_url = 'https://movie.douban.com/cinema/nowplaying/guangzhou/'

resp = requests.get(movie_douban_url, headers=headers)
# print(type(resp.text))
# print(type(resp.content))
text = resp.text

# %%
from lxml import etree
htmlele = etree.HTML(text)

# %%
ul = htmlele.xpath('//ul[@class="lists"]')[0]

# %%
lis = ul.xpath('./li')
movies = []
for li in lis:
    movie = {
        'movie_title' : li.xpath('@data-title')[0],
        'movie_score' : li.xpath('@data-score')[0],
        'movie_star' : li.xpath('@data-star')[0],
        'movie_duration' : li.xpath('@data-duration')[0],
        'movie_region': li.xpath('@data-region')[0],
        'movie_diretor' : li.xpath('@data-director')[0],
        'movie_actors' : li.xpath('@data-actors')[0],
        'movie_subnail' : li.xpath('.//a/@href')[0]
    }
    movies.append(movie)
print(len(movies))
# Out:
# 30

# %%
ult = etree.tostring(ul, encoding='utf-8').decode('utf-8')

# %% [markdown]
# ## 3.5 爬取电影天堂

# %%
import requests
from lxml import etree

headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 Safari/537.36',
    'Referer':'http://www.dytt8.net/'
}

movie_ygdy8_url_domain = 'http://www.ygdy8.net'

def get_movie_url(movie_page_url):
    resp = requests.get(movie_page_url, headers = headers)
    # 网页的编码方式不一定是‘utf-8’, 查看源代码，发现是‘gb2312’,可以使用'gbk'进行解码
    # 此处只是获取到href，如果一定要解析成gbk，可能会存在乱码
    respt = resp.text
    movies_html = etree.HTML(respt)
    movie_urls = movies_html.xpath('//a[@class="ulink"]/@href')
    movie_detail_urls = map(lambda url: movie_ygdy8_url_domain+url, movie_urls)
    return movie_detail_urls

def get_movie_detail(movie_detail_urls):
    movie = {}
    respm = requests.get(movie_url, headers=headers)
    respmt = respm.content.decode('gbk')
    movie_html = etree.HTML(respmt)
    movie_title = movie_html.xpath('//div[@class="title_all"]//font[@color="#07519a"]/text()')[0]
#     movie_title = etree.tostring(movie_title, encoding='utf-8').decode('utf-8')
    movie_infos = movie_html.xpath('//div[@id="Zoom"]')[0]
    movie_img = movie_infos.xpath('.//img/@src')
    movie_cover = movie_infos.xpath('.//img/@src')[0]
    movie_screenshot = movie_infos.xpath('.//img/@src')[1]
    movie_info = movie_infos.xpath('.//text()')
    
    def parse_info(info, rule):
        return info.replace(rule, '').strip()
    for index, info in enumerate(movie_info):
        if info.startswith('◎年　　代'):
            movie_year = parse_info(info, '◎年　　代')
        elif info.startswith('◎产　　地'):
            movie_country = parse_info(info, '◎产　　地')
        elif info.startswith('◎类　　别'):
            movie_category = parse_info(info, '◎类　　别')
        elif info.startswith('◎上映日期'):
            movie_date = parse_info(info, '◎上映日期')
        elif info.startswith('◎豆瓣评分'):
            movie_score = parse_info(info, '◎豆瓣评分')
        elif info.startswith('◎片　　长'):
            movie_duration = parse_info(info, '◎片　　长')
        elif info.startswith('◎导　　演'):
            movie_director = parse_info(info, '◎导　　演')
        elif info.startswith('◎主　　演'):
            movie_mactor = parse_info(info, '◎主　　演')
            actors=[movie_mactor]
            for x in range(index+1, len(movie_info)):
                movie_actor = movie_info[x].strip()
                if movie_actor.startswith('◎'):
                    break
                actors.append(movie_actor)
        elif info.startswith('◎简　　介'):
            profile = parse_info(info, '◎简　　介')
            profile=[profile]
            for x in range(index+1, len(movie_info)):
                movie_profile=movie_info[x].strip()
                if movie_profile.startswith('【下载地址】'):
                    break
                profile.append(movie_profile)
    download_url = movie_html.xpath('//td[@bgcolor="#fdfddf"]/a/@href')
    movie = {
        'title': movie_title,
        'cover': movie_cover,
        'screenshot': movie_screenshot,
        'year':movie_year,
        'country':movie_country,
        'category':movie_category,
        'date':movie_date,
        'score':movie_score,
        'duration':movie_duration,
        'director': movie_director,
        'actors':actors,
        'profile':profile,
        'download_url':download_url
    }
    return movie
    
def store_movie():
    pass

def main():
    movies = []
    for i in range(1,182):
        movie_page_url = 'http://www.ygdy8.net/html/gndy/dyzz/list_23_{}.html'.format(i)
        movie_detail_urls = get_movie_url(movie_page_url)
        for movie_detail in movie_detail_urls:
            movie_detail = get_movie_detail(movie_detail_urls)
            movies.append(movie_detail)
            print(movies)
            break
        break
    
    
if __name__=='__main__':
    main()
# Out:
# [{'title': '2018年科幻动作《巨齿鲨》HD国英双语双字', 'cover': 'https://extraimage.net/images/2018/09/18/344c1d5d4591da0a5fa6b2f82721859a.jpg', 'screenshot': 'https://lookimg.com/images/2018/10/05/YSU8h.jpg', 'year': '2018', 'country': '美国/中国/中国香港', 'category': '动作/科幻/惊悚', 'date': '2018-08-10(美国)/2018-08-10(中国)', 'score': '5.8/10 from 1,341 users', 'duration': '115分钟(中国大陆)/113分钟', 'director': '乔·德特杜巴 Jon Turteltaub', 'actors': ['杰森·斯坦森 Jason Statham', '李冰冰 Bingbing Li', '雷恩·威尔森 Rainn Wilson', '鲁比·罗丝 Ruby Rose', '赵文瑄 Winston Chao', '佩吉·肯尼迪 Page Kennedy', '杰西卡·麦克娜美 Jessica McNamee', '奥拉维尔·达里·奥拉夫松 Ólafur Darri Ólafsson', '罗伯特·泰勒 Robert Taylor', '蔡书雅 Sophia Cai', '丘增 Masi Oka', '克利夫·柯蒂斯 Cliff Curtis', '安佑森 Yoson An', '罗伯·基帕-威廉姆斯 Rob Kipa-Williams', '维他亚·潘斯林加姆 Vithaya Pansringarm', '安得烈·格兰杰 Andrew Grainger', '蒂姆·王 Tim Wong', '史蒂文·A·戴维斯 Steven A. Davis', '托万达·马尼莫 Tawanda Manyimo', '买红妹 Hongmei Mai'], 'profile': ['', '一项由中国主导的国际科研项目，正在马里亚纳海沟深处进行时，遭遇未知生物攻击，科研人员被困海底。前美国海军陆战队深海潜水专家乔纳斯·泰勒受命前往营救，再度遭遇数年前曾经在深海给自己留
# ...

# %%
http://www.ygdy8.net/html/gndy/dyzz/20181005/57549.html

# %%
import os 
os.getcwd()
# Out:
# 'D:\\Program Files\\cmder\\myfiles\\PythonAnalysis\\Spider'
